# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.path.dirname('get_naver_news'), '..')))
from module.get_mcp_client import get_mcp_client
from module.get_news_origin import get_news_origin

import json
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
async def get_news(query,k=10):
    client = get_mcp_client()
    tools = await client.get_tools(server_name="naver-search-mcp")
    tool = next(tool for tool in tools if tool.name == "search_news")

    response = await tool.ainvoke({
        "query": query,
        "display": k,  # 최대 100
        "start": 1,
        "sort": "date"  # 날짜순 정렬
    })
    return json.loads(response)  # JSON 문자열을 dict로 변환
    

result = await get_news('삼성전자')

# %%
get_news_origin(result)
# Out:
# [Document(metadata={'source': 'https://n.news.naver.com/mnews/article/277/0005655809?sid=101'}, page_content='\n"삼성, D램 최대 30%·낸드 10% 인상…AI 서버 수요 반영"\n\n\n\t\t\t삼성전자가 4분기 D램 가격을 최대 30% 인상하기로 했다. 낸드플래시 가격도 5~10% 올린다. 글로벌 주요 메모리 업체들이 일제히 가격 인상에 나선 것은 인공지능(AI) 서버 수요가 폭발적으로 늘고 있기 때문이다.22일 반도체 업계와 외신에 따르면 삼성전자는 최근 주요 고객사에 이 같은 가격 조정을 통보했다. 앞서 마이크론과 샌디스크도 가격 인상을 선언한 바 있어 메모리 세계 1위인 삼성전자까지 동참하면서 업계 전반에 걸쳐 가격 상승이 본격화됐다.\n\n\n\n젠슨 황과 인사나누는 이재용 회장. 연합뉴스업계는 구글과 마이크로소프트 등 미국 빅테크 기업은 물론 텐센트, 바이두 등 중국 업체들이 대규모 AI 인프라 투자에 나서면서 고용량 메모리 수요가 급증한 데 따른 조치로 보고 있다. 이에 따라 삼성전자와 SK하이닉스에는 고대역폭메모리(HBM), 그래픽용 D램(GDDR7), 저전력 D램(LPDDR5) 등 서버용 제품 주문이 몰리고 있다. 낸드플래시 기반 솔리드스테이트드라이브(SSD) 수요도 동반 확대되는 추세다.한편 삼성전자 주가는 이날 4.77% 오른 8만3500원에 거래를 마쳤다.\n\n'),
#  Document(metadata={'source': 'https://n.news.naver.com/mnews/article/028/0002767673?sid=101'}, page_content='\n국세청 “롯데카드 국세납부 일시 중단”\n\n\n“해킹 피해 선제 예방 차원”\n\n\n\n지난 19일 서울 종로구 롯데카드 본사에 고객 개인정보 유출 해킹 사건과 관련해 카드센터 상담소가 마련돼 있다. 연합뉴스국세청이 롯데카드 고객정보 해킹 사건으로 인한 피해를 예방하기 위해 롯데카드를 사용한 국세 납부를 일시 중단했다. 삼성전자도 자사 온라인몰 결제에서도 카드정보를 입력하는 방식의 롯데카드 결제를 막았다.22일 국세청 누리집을 보면 국세청은 지난 18일부터 롯데카드를 사용한 국세 납부를 중단하고 있다. 홈택스에서 가능한 조회납부·자진납부·타인세금납부 및 세무서 방문 등 모든 신용카드 납부 채널에서 롯데카드 사용을 막았다.국세청은 누리집에 공지글을 올려 “국세 신용카드 납부는 취소가 되지 않으므로 피해 예방을 위한 선제 대응 조처로 롯데카드 납부를 일시 중단한다”며 “롯데카드사에서 부정사용 우려 카드 재발급 조처를 완료한 뒤 국세 납부가 재개될 예정”이라고 말했다.\n\n\n\n지난 18일 롯데카드는 해킹으로 자사 고객 297만명의 정보가 유출됐으며 이 가운데 28만명은 카드번호와 비밀번호 두 자리, 유효기간, 카드보안코드(CVC) 등이 유출돼 부정사용 가능성이 있다고 밝혔다.\n\n'),
#  Document(metadata={'source': 'https://n.news.naver.com/mnews/article/015/0005188520?sid=101'}, page_content='\n한·일·대만 증시는 상승, 인도와 홍콩증시 하락\n\n\n삼성전자,TSMC,도쿄일렉트론 등 반도체주 일제 상승이 기사는 국내 최대 해외 투자정보 플랫폼 한경 글로벌마켓에 게재된 기사입니다.\n\n\n\n사진=EPA도널드 트럼프 대통령이 주말에 발표한  H-1B 비자에 대한 새로운 규제 조치에 22일(현지시간) 아시아에서 인도와 홍콩 증시는 하락세를 보였으나 일본과 한국 대만 증시는 기술주 주도로 상승을 지속했다. 일본의 닛케이 225지수는 이 날 0.99% 오른 45.493.66으로 다시 최고치를 경신했다. 지난 주말 일본은행(BOJ)의 상장지수펀드(ETF) 매각 결정이 시장에 큰 영향을 미치지 않을 것이라는 인식으로 매수세가 유입되고 도쿄일렉트론 등 반도체 관련 대형주들이 강세를 주도했다. 한국 증시는 삼성전자가 4.77% 급등하면서 코스피가 0.68% 상승해 재차 최고치를 경신했다. 이 날 삼성전자는 HBM(고대역폭메모리) HBM3E 12단 제품의 엔비디아 품질 테스트를 통과할 가능성이 높다는 소식과 모건 스탠리가 D램 가격 상승을 예상하며 목표주가를 12% 상향한 보고서로 크게 올랐다.대만 자취엔 지수도 미국과 중국의 AI인프라 투자 등에 대한 기대에 힘입어 1.1% 오르면서 역대 최고치를 기록했다. TSMC 주가는 이 날 1.4% 상승하면서 역대 최고치를 경신했다. 인도의 벤치마크 지수는 이 날 0.2% 하락했다. 지난 주말 트럼프 행정부가 기업들이 새로운 H-1B 근로자 비자를 받을 때 10만달러를 지불하도록 할 것이라고 발표한 후 인도 IT기업들이 큰 타격을 받을 것으로 예상됐다. 인포시스와 타타 컨설턴시 등 인도 정보기술업계의 아웃소싱 부문은 2,830억 달러(약 394조원) 에 달하는 매출의 절반 이상을 미국에서 얻고 있다. 미국 증시는 이 날 S&P 선물이 0.3%, 나스닥 선물 0.4%, 다우지수 선물도 0.3% 하락하면서 개장전에 하락세를 보였다. 유럽의 광범위한 스톡스600 지수는 오전 장에서 0.3% 내렸다. 캐피털탓컴의 수석 재무 분석가인 카일 로다는 트럼프 대통령의 H-1B 비자 발급비용 대폭 인상조치는 "미국내 기술인력 부족으로 해외 인력을 활용해온 미국 기술 기업들의 운영 비용과 마진에 위험이 될 것”이라고 지적했다. 거시경제 측면에서, 투자자들은 연준이 향후 점진적인 금리 인하를 시사한 후 올해 남은 두 번의 정책 회의에서 두 차례의 금리 인하가 있을 것으로 예상하고 있다. 이번 주에 연준의 정책 입안자들이 여러 명 연설할 것으로 예상된다. 금요일(26일)에는 연준이 선호하는 인플레이션 지표인 8월 개인소비지출(PCE) 데이터가 발표될 에정이다. IG의 시장 분석가인 토니 시카모어에 따르면, 핵심 PCE 가격 지수는 월별로 0.2% 상승할 것으로 예상된다. 이에 따라 연율 증가율은 7월과 동일한 2.9%로 유지되고 4월에 기록한 최저치 2.6%보다 높아진다. 미국 달러화 가치를 다른 6개 통화 대비 나타내는 달러 지수는 0.09% 상승한 97.814를 기록했다. 이 지수는 올들어 거의 10% 하락했지만, 하락폭의 상당 부분은 2025년 상반기에 발생했다. 지난 주말 일본은행은 두 명의 위원이 금리 인상을 주장한 가운데서도 금리 동결을 결정했다. 이 여파로 엔화는 1달러당 148.20엔으로 약간 약세를 보였다. OCBC은행 투자전략부문 전무이사인 바수 메논은 그럼에도 일본중앙은행이 점차 금리 인상쪽으로 전환하고 있다는 신호가 명확해졌으며 시장에서도 이렇게 받아들일 것이라고 말했다. 이에 따라 “단기적으로 엔화가 강해질 수 있으며 이는 일본 주식과 채권에 좋은 소식이 아닐 수 있다”고 언급했다. \n\n'),
#  Document(metadata={'source': 'https://n.news.naver.com/mnews/article/022/0004070202?sid=101'}, page_content='\n감사 마음 담아… 군인·경찰·소방 공무원 대상 가전 바겐세일\n\n\n \n\n\n\n  삼성전자 모델들이 22일 군인·경찰·소방·교정 공무원 등을 대상으로 풍성한 혜택을 제공하는 ‘K-히어로 페스타’를 소개하고 있다. 이번 행사는 11월 30일까지로, TV·냉장고·세탁건조기·식기세척기·인덕션·스마트폰·PC·태블릿 등 다양한 최신 제품을 출고가 대비 최대 50% 할인된 가격으로 만날 수 있다.\n\n'),
#  Document(metadata={'source': 'https://n.news.naver.com/mnews/article/374/0000464839?sid=101'}, page_content="\n[주간 증시 전망] 경제는 부진, 증시는 활황…5천피 vs 버블론?\n\n\n■ 경제현장 오늘 '주간 증시 전망' -\xa0 김학균 신영증권 리서치 센터장코스피는 오늘도 사상 최고치를 경신했습니다. 과감하게 빚투까지 하는 투자자가 있는 반면, 단기간 상승 폭이 너무 커 자금을 빼는 분들도 많죠. 이재명 정부가 희망을 던진 임기내 5천피 시대가 가능할지에 대해서도 시각이 나뉩니다. 이런 시기에\xa0우리는 어떻게 투자 전략을 가져야 할지, 김학균 신영증권 리서치센터장 모시고 이야기 나눠보겠습니다.Q. '5000p 시대를 위한 투자 대전환'이라는 책을 쓰셨던데요. 30년 가까이 시장을 분석하고 있는데, 최근 코스피 어떻게 보고 계십니까?Q. 실물경제가 부진하고 기업들의 실적 전망이 그다지 낙관적이지 않은데 증시가 어떻게 활황을 이룰 수 있는 걸까요? 그 원동력이 유지될 수 있을까요?Q. 증시가 이렇게 오를 때마다 버블 논란이 있곤 한데, 이번 사이클의 정점은 어디까지로 보고 계신가요?Q. 뉴욕 증시는 어떻게 보고 계십니까? 지난주에 25bp 기준금리를 낮췄지만 미국 재정적자는 크고, 고용은 좋지 않은데. 미국증시 불패론은 여전히 이어가는 듯한데요?Q. 미국증시도 M7 위주로 오르고 있고, 우리 반도체주 SK하이닉스와 삼성전자도 많이 올랐고요. 중국 증시도 알리바바 등 AI주들이 오르고 있는데,앞으로 반도체와 AI주에 대해서는 어떻게 보십니까?Q. \xa0AI에 대한 높은 기대감 그 자체가 위험 요인이라고 볼 수는 없을까요? 높은 기대감을 충족시킬 만큼 실적이 안나온다면 큰 조정이 올 수도 있지 않을까요?Q. 정부는 양도소득세 대상 대주주 기준 강화를 철회했습니다. 배당소득 분리과세에 대해선 정부가 예고한 최고세율 35%를 낮춰달라는 게 투자자들의 요구인데 정부는 꺼리는 분위기입니다. 어떻게 보십니까?Q. 연준 금리 인하 사이클에서 어떤 관점으로 투자 전략을 가져가는 것이 좋을까요?(자세한 내용은 동영상을 시청하시기 바랍니다.)\xa0당신의 제보가 뉴스로 만들어집니다.SBS Biz는 여러분의 제보를 기다리고 있습니다.홈페이지 = https://url.kr/9pghjn\n\n"),
#  Document(metadata={'source': 'https://n.news.naver.com/mnews/article/028/0002767672?sid=101'}, page_content='\n반도체 호황에 삼성전자·SK하이닉스 순항…‘마이크론 날개’ 날까\n\n\n\n\n\n\n반도체 훈풍에 삼성전자, 에스케이(SK)하이닉스 등 국내 기업의 3분기 실적 전망치가 높아지고 있다. 클립아트코리아생성형 인공지능(AI)을 구동하는 그래픽처리장치(GPU)의 핵심 부품으로 꼽히는 고대역폭메모리(HBM)가 이끄는 반도체 호황으로 삼성전자, 에스케이(SK)하이닉스 등 국내 기업의 3분기 실적 눈높이가 높아지고 있다. 오는 23일(현지시각) 발표하는 미국 반도체 기업 마이크론(마이크론 테크놀로지)의 실적이 한국 기업의 실적 가늠자가 될 것으로 보인다.22일 금융정보업체 에프엔가이드 자료를 보면, 전날 기준 증권사들의 삼성전자 3분기 영업이익 예상치를 취합한 컨센서스는 9조2191억원이다. 한 해 전 같은 기간(9조1800억원)과 유사한 수준이지만, 지난달 컨센서스(8조7531억원)보다는 5.3%(4660억원) 높아졌다. 탄탄한 메모리 반도체 업황 속에 삼성전자가 지난 7월 내놓은 갤럭시 제트(Z) 폴드·플립 등도 판매 호조를 보여주고 있기 때문으로 풀이된다.에스케이증권은 삼성전자의 3분기 영업이익 예상치를 지난해 같은 기간보다 10.5% 늘어난 10조5천억원으로 제시했다. 인공지능(AI) 서버 중심의 투자가 일반 서버용 반도체 투자로 확대되고, 6세대 고대역폭메모리(HBM4) 시장 진입도 기대된다는 분석이다. 하나증권 역시 삼성전자의 메모리 반도체 영업이익 전망치를 5조6천억원으로 기존 4조7천억원 대비 19%나 올려잡았다.엔비디아에 고대역폭메모리를 독점 공급하는 에스케이하이닉스의 실적 전망치도 높아지는 추세다. 전날 기준 에스케이하이닉스의 3분기 영업이익 전망치는 10조5577억원이다. 6개월 전 9조90억원에서 10조원대로 높아진 것이다.에스케이하이닉스는 고대역폭메모리 공급이 원활한 데다가, 서버 주문이 늘어나며 일반 메모리 공급도 늘어날 것으로 전망된다. 한동희 에스케이증권 연구원은 “에스케이하이닉스는 업계 내에서 샘플(견본)을 내놓는 속도가 가장 빠르다”며 “원가 경쟁력을 바탕으로 한 이익 점유율, 수익성 차별화로 우위를 유지할 것”이라고 내다봤다.메모리 반도체 업계 가운데 가장 먼저 분기 실적을 발표해 이른바 ‘업황 풍향계’로 불리는 미국 마이크론의 4분기(6~8월) 실적 발표는 23일(현지시각)로 예정돼 있다. 월가 애널리스트들은 마이크론 4분기 매출이 전년 동기 대비 43% 증가한 111억2천만달러에 이를 것으로 전망하고 있다.\n\n')]
